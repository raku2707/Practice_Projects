# %% [markdown]
# # Import libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read file and fetch top 5 data from dataset

# %%
#Create dataframe and read csv file from github

Census_pro = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')


#Fetch top 5 data
Census_pro.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
#Shape of dataset

Census_pro.shape
# Out:
# (32560, 15)

# %%
#Columns in dataset

Census_pro.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
#Information about each column

Census_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# __Dataset Information__
#
#     Dataset have 32560 entries, 0 to 32559
#     Data having 32560 Rows and 15 columns
#     From above information we can say data having 32560 non-null values in all the columns
#     Data having 6 int data type values and 9 object data type.

# %%
#Checking null values from dataset

Census_pro.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# Here we can see data set having all the filled with some values, no null is present.

# %% [markdown]
# __Checkign any space or '?' , values filled in the columns__

# %%
#Lets check the wrong entries

Census_pro.isin([" ?"]).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %% [markdown]
# In our data Workclass, Occupation. Native_country are having wrong entries. Lets drop these Rows

# %%
Census_pro.replace(to_replace=" ?", value=np.nan, inplace= True)

# %%
Census_pro =Census_pro.dropna()
Census_pro
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
#Again we check null values

Census_pro.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
#     All values are replace now.

# %%
Census_pro.sample(5)
# Out:
#        Age   Workclass  Fnlwgt      Education  Education_num  \
# 23795   30     Private  361742   Some-college             10
# 18629   19     Private  552354           12th              8
# 630     49   Local-gov  120451           10th              6
# 31686   21     Private  197997   Some-college             10
# 4197    26     Private  229523        HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 23795   Married-civ-spouse     Exec-managerial      Husband   White     Male
# 18629        Never-married   Machine-op-inspct    Own-child   White     Male
# 630              Separated       Other-service    Unmarried   Black   Female
# 31686        Never-married        Adm-clerical    Own-child   White     Male
# 4197    Married-civ-spouse   Machine-op-inspct         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Lets first seperate categorical and Numerical colums.

# %%
#First seperate categorical column from dataset

categorical = Census_pro.select_dtypes(include=[np.object])
categorical.head()
# Out:
#            Workclass   Education       Marital_status          Occupation  \
# 0   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 1            Private     HS-grad             Divorced   Handlers-cleaners
# 2            Private        11th   Married-civ-spouse   Handlers-cleaners
# 3            Private   Bachelors   Married-civ-spouse      Prof-specialty
# 4            Private     Masters   Married-civ-spouse     Exec-managerial
#
#      Relationship    Race      Sex  Native_country  Income
# 0         Husband   White     Male   United-States   <=50K
# 1   Not-in-family   White     Male   United-States   <=50K
# 2         Husband   Black     Male   United-States   <=50K
# 3            Wife   Black   Female            Cuba   <=50K
# 4            Wife   White   Female   United-States   <=50K

# %% [markdown]
# # Univariate Aanalysis
#
# ### Now plotting countplot and pieplot for better visualization in categorical features

# %%
#Visualize countplot from workclass column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Workclass'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Workclass', fontsize=15 )
plt.title('Workclass', fontsize=15)


#Visualize pie plot from Workclass column

plt.subplot(1,2,2)
categorical.groupby('Workclass').size().plot(kind='pie', autopct='%.2f')
plt.title('Workclass', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 73.89 percent of the population working in Private sector.

# %%
#Visualize countplot from Education column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Education'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Education', fontsize=15 )
plt.title('Education', fontsize=15)


#Visualize pie plot from Education column

plt.subplot(1,2,2)
categorical.groupby('Education').size().plot(kind='pie', autopct='%.2f')
plt.title('Education', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 32.62 percent population is HS-grad, only 1.24 percent of the population is doctrate and many less population is Preschool.

# %%
#Visualize countplot from Marital_status column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Marital_status'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Marital_status', fontsize=15 )
plt.title('Marital_status', fontsize=15)


#Visualize pie plot from Marital_status column

plt.subplot(1,2,2)
categorical.groupby('Marital_status').size().plot(kind='pie', autopct='%.2f')
plt.title('Marital_status', fontsize=15)
plt.show()

# %% [markdown]
# We can see 46.63 percent population is married civ spouse, 32.24 percent population is Never married and only 0.7 percent popultion is Married AF spouse.

# %%
#Visualize countplot from Occupation column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Occupation'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Occupation', fontsize=15 )
plt.title('Occupation', fontsize=15)


#Visualize pie plot from Occupation column

plt.subplot(1,2,2)
categorical.groupby('Occupation').size().plot(kind='pie', autopct='%.2f')
plt.title('Occupation', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 13.39 percent population is Prof-specialty, 13.36 percent population is Craft repair, 13.24 percent population is Excel Managerial, and 12.33 percent population is Adm clerical. So it means around 52 percent of the population is at very good posotion.
#
# Only 0.47 percent of the population is Priv-house servent.

# %%
#Visualize countplot from Relationship column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Relationship'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Relationship', fontsize=15 )
plt.title('Relationship', fontsize=15)


#Visualize pie plot from Occupation column

plt.subplot(1,2,2)
categorical.groupby('Relationship').size().plot(kind='pie', autopct='%.2f')
plt.title('Relationship', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 41.32 percent of the population have relationship as husband, means they are male and 2.95 percent population is other relative.

# %%
#Visualize countplot from Race column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Race'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Race', fontsize=15 )
plt.title('Race', fontsize=15)


#Visualize pie plot from Race column

plt.subplot(1,2,2)
categorical.groupby('Race').size().plot(kind='pie', autopct='%.2f')
plt.title('Race', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 85.98 percent population is White and only 9.34 pepole are black.

# %%
#Visualize countplot from Sex column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Sex'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Sex', fontsize=15 )
plt.title('Sex', fontsize=15)


#Visualize pie plot from Sex column

plt.subplot(1,2,2)
categorical.groupby('Sex').size().plot(kind='pie', autopct='%.2f')
plt.title('Sex', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 67.57 percent of the population is Male and 32.43 percent of the population is female.

# %%
#Visualize countplot from Native_country column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Native_country'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Native_country', fontsize=15 )
plt.title('Native_country', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Native_country')

# %% [markdown]
# Here we can see more than 90 percent of the populaton is from United-states.

# %%
#Visualize countplot from Income column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=categorical['Income'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Income', fontsize=15 )
plt.title('Income', fontsize=15)


#Visualize pie plot from Income column

plt.subplot(1,2,2)
categorical.groupby('Income').size().plot(kind='pie', autopct='%.2f')
plt.title('Income', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see Our Target columns having very good information. 75.11 percent of population have anual income <=50K
# Only 24.89 percentage of pepole are >=50K

# %% [markdown]
# ## Now plotting countplot and pieplot for better visualization in numerical features

# %% [markdown]
# From histogram, we can predict most of The working age of US pupulation is between 20-50
# very few pepole are working in the age above 50.

# %%
#First seperate numerical column from dataset

numerical = Census_pro.select_dtypes(include = [np.int64])
numerical.head()
# Out:
#    Age  Fnlwgt  Education_num  Capital_gain  Capital_loss  Hours_per_week
# 0   50   83311             13             0             0              13
# 1   38  215646              9             0             0              40
# 2   53  234721              7             0             0              40
# 3   28  338409             13             0             0              40
# 4   37  284582             14             0             0              40

# %%
#Visualize histplot from age column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,5))

sns.histplot(numerical['Age'], bins= 8)
plt.xlabel('Age', fontsize=15 )
plt.ylabel('Count', fontsize=15 )
plt.title('Age', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Age')

# %% [markdown]
# From histogram, we can predict most of The working age of US pupulation is between 20-50
#
# Very few pepole are working in the age above 50.

# %%
#Visualize countplot from Education_num column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.countplot(y=numerical['Education_num'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Education_num', fontsize=15 )
plt.title('Education_num', fontsize=15)


#Visualize pie plot from Education_num column

plt.subplot(1,2,2)
numerical.groupby('Education_num').size().plot(kind='pie', autopct='%.2f')
plt.title('Education_num', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see Education_num indicates number of years of education, 32.62 percent pepole are having 9 years of education ony, 22.14 are having 10 years education. Ppulation with higher education is low.

# %%
#Visualize distplot from capital gain column

plt.figure(figsize=(15,5))

sns.distplot(numerical['Capital_gain'])
plt.xlabel('Capital_gain', fontsize=15 )
plt.ylabel('Density', fontsize=15 )
plt.title('Capital_gain', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Capital_gain')

# %% [markdown]
# Probablity for 0 capital gain is very high, data having outliers and skewness

# %%
#Visualize distplot from capital loss column

plt.figure(figsize=(15,5))

sns.distplot(numerical['Capital_loss'])
plt.xlabel('Capital_loss', fontsize=15 )
plt.ylabel('Density', fontsize=15 )
plt.title('Capital_loss', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Capital_loss')

# %% [markdown]
# Probablity for 0 capital loss is very high, data having outliers and skewness.

# %%
#Visualize distplot from Hours_per_week column

sns.set_theme(style="darkgrid")
plt.figure(figsize=(32,6))

plt.subplot(1,2,1)
sns.distplot(numerical['Hours_per_week'])
plt.xlabel('Count', fontsize=15 )
plt.ylabel('Hours_per_week', fontsize=15 )
plt.title('Hours_per_week', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Hours_per_week')

# %% [markdown]
# We can see probablity of 40 hrs/week is very high.

# %% [markdown]
# ## Here we will analize our data with target column,
#
# We will check how target is effected due to Features columns.

# %%
#Visualize countplot from Independent feature (Workclass) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Workclass'], hue='Income', data= Census_pro)
plt.xlabel('Workclass', fontsize= 15)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Workclass'])
# Out:
# Workclass   Federal-gov   Local-gov   Private   Self-emp-inc  \
# Income
#  <=50K              578        1458     17410            474
#  >50K               365         609      4876            600
#
# Workclass   Self-emp-not-inc   State-gov   Without-pay
# Income
#  <=50K                  1785         934            14
#  >50K                    714         344             0

# %% [markdown]
# We have max population working in Private setor whose income income is <=50K per year.
#
# At same time pepole working in private sector are more as compared to other setcor, whose income is >=50K per year.

# %%
#Visualize countplot from Independent feature (Education) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Education'], hue='Income', data= Census_pro)
plt.xlabel('Education', fontsize= 15)
plt.xticks(rotation=70)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Education'])
# Out:
# Education   10th   11th   12th   1st-4th   5th-6th   7th-8th   9th  \
# Income
#  <=50K       761    989    348       145       276       522   430
#  >50K         59     59     29         6        12        35    25
#
# Education   Assoc-acdm   Assoc-voc   Bachelors   Doctorate   HS-grad  \
# Income
#  <=50K             752         963        2917          95      8223
#  >50K              256         344        2126         280      1617
#
# Education   Masters   Preschool   Prof-school   Some-college
# Income
#  <=50K          709          45           136           5342
#  >50K           918           0           406           1336

# %% [markdown]
# Here we can see the graph indicates that population with higher degree have more chance to have income >=50K

# %%
#Visualize countplot from Independent feature (Marital_status) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Marital_status'], hue='Income', data= Census_pro)
plt.xlabel('Marital_status', fontsize= 15)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Marital_status'])
# Out:
# Marital_status   Divorced   Married-AF-spouse   Married-civ-spouse  \
# Income
#  <=50K               3762                  11                 7666
#  >50K                 452                  10                 6399
#
# Marital_status   Married-spouse-absent   Never-married   Separated   Widowed
# Income
#  <=50K                             339            9255         873       747
#  >50K                               31             470          66        80

# %% [markdown]
# We can see Married civ spouse population is having higher number of Income which >=50k, as compared to other columns,
#
# we can say Married civ spouse is having higher possiblity to have income >=50K
#
# Other category not showing very good relation.

# %%
#Visualize countplot from Independent feature (Occupation) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Occupation'], hue='Income', data= Census_pro)
plt.xlabel('Occupation', fontsize= 15)
plt.xticks(rotation=70)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Occupation'])
# Out:
# Occupation   Adm-clerical   Armed-Forces   Craft-repair   Exec-managerial  \
# Income
#  <=50K               3222              8           3122              2055
#  >50K                 498              1            908              1937
#
# Occupation   Farming-fishing   Handlers-cleaners   Machine-op-inspct  \
# Income
#  <=50K                   874                1267                1721
#  >50K                    115                  83                 245
#
# Occupation   Other-service   Priv-house-serv   Prof-specialty  \
# Income
#  <=50K                3080               142             2227
#  >50K                  132                 1             1811
#
# Occupation   Protective-serv   Sales   Tech-support   Transport-moving
# Income
#  <=50K                   434    2614            634               1253
#  >50K                    210     970            278                319

# %% [markdown]
# We can see Occupation like Exce-managerial and Prof-specialty having higher population with income >=50K.
#
# In other occupation count is very less for income>=50K
#
# It indicates occupation have good impact to have income>=50K

# %%
#Visualize countplot from Independent feature (Race) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Race'], hue='Income', data= Census_pro)
plt.xlabel('Race', fontsize= 15)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Race'])
# Out:
# Race     Amer-Indian-Eskimo   Asian-Pac-Islander   Black   Other   White
# Income
#  <=50K                  252                  647    2451     210   19093
#  >50K                    34                  248     366      21    6839

# %% [markdown]
# Here we can see majority of population is White,  so there change of getting income>=50K, Is higher.

# %%
#Visualize countplot from Independent feature (Relationship) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Relationship'], hue='Income', data= Census_pro)
plt.xlabel('Relationship', fontsize= 15)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Relationship'])
# Out:
# Relationship   Husband   Not-in-family   Other-relative   Own-child  \
# Income
#  <=50K            6784            6902              854        4402
#  >50K             5679             823               35          64
#
# Relationship   Unmarried   Wife
# Income
#  <=50K              2999    712
#  >50K                213    694

# %% [markdown]
# Here we can see husband colummn having higher count for income>=50K.
#
# It also indiactes Married man population count is higher than than the unmarried.

# %%
#Visualize countplot from Independent feature (Sex) with target feature (Income)

plt.figure(figsize=(15,5))
sns.countplot(Census_pro['Sex'], hue='Income', data= Census_pro)
plt.xlabel('Sex', fontsize= 15)
plt.ylabel('Count', fontsize= 15)
plt.show()

# %%
pd.crosstab(Census_pro['Income'], Census_pro['Sex'])
# Out:
# Sex      Female   Male
# Income
#  <=50K     8670  13983
#  >50K      1112   6396

# %% [markdown]
# We can see Male population is having highher count as compared to Female, for income>=50K

# %% [markdown]
# # Lets first encode the Target column

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
Census_pro['Income']=le.fit_transform(Census_pro['Income'])

# %% [markdown]
# Here we can see number as most of the population in working with income<=50.

# %%
#Lets visualize distplot from Target column (Income) with age column

plt.figure(figsize=(10,7))
sns.distplot(Census_pro[Census_pro['Income']==0]['Age'], hist=False)
sns.distplot(Census_pro[Census_pro['Income']==1]['Age'], hist=False )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Here we can see initially when the age is less, probablity of having income <=50K is High.
#
# As age increases the probablity of having income >=50K is is increasing, it is high at age of 40-50

# %%
#Lets visualize distplot from Target column (Income) with Education_num column

plt.figure(figsize=(10,6))
sns.distplot(Census_pro[Census_pro['Income']==0]['Education_num'], hist=False )
sns.distplot(Census_pro[Census_pro['Income']==1]['Education_num'], hist=False )
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %% [markdown]
# Here we can clearly see with increase in the number of Education chance of having income>=50K is high.
#
# At point where education_num >12.5, we cans see drastic chaneg in the population with income>=50K.

# %%
#Lets visualize distplot from Target column (Income) with Hours_per_week column

plt.figure(figsize=(10,6))
sns.distplot(Census_pro[Census_pro['Income']==0]['Hours_per_week'], hist=False )
sns.distplot(Census_pro[Census_pro['Income']==1]['Hours_per_week'], hist=False )
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Density'>

# %% [markdown]
# We can see Initialy the population with income<=50K is high as compare to population with income >=50K. But the graph changes with working hours >50, we can see increse in the population having income>=50.
#
# This might be due to extra workign hours.(overtime)

# %% [markdown]
# ## Bi Variate and Multivariate analysis.

# %%
#Visualize countplot from Target column with Sex and Age column

plt.figure(figsize=(10, 6))
sns.barplot(Census_pro['Sex'],Census_pro['Age'], hue='Income', data= Census_pro)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Workclass', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see for male and female both as age increases, the population count for income>=50K, also increases.

# %%
#Visualize countplot from Target column with Occupation and Education_num column

plt.figure(figsize=(20, 6))
sns.barplot(Census_pro['Occupation'],Census_pro['Education_num'], hue='Income', data= Census_pro)
plt.xlabel('Occupation', fontsize=15)
plt.xticks(rotation = 80)
plt.ylabel('Education_num', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see With increase in the Education years, income also increase in same occupation. Population having same occupation, but due to Higher Education They are earning >=50K, in same occuaption.

# %%
#Visualize countplot from Target column with Education and Age column

plt.figure(figsize=(20, 6))
sns.barplot(Census_pro['Education'],Census_pro['Age'], hue='Income', data= Census_pro)
plt.xlabel('Education', fontsize=15)
plt.xticks(rotation = 80)
plt.ylabel('Age', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see Age is having considerable effect on Income With same eduaction background, pepole earning more due to their age diffrence, or indiractly we can say due to more experience.

# %%
#Visualize countplot from Target column with Occupation and Hours_per_week column

plt.figure(figsize=(20, 6))
sns.barplot(Census_pro['Occupation'],Census_pro['Hours_per_week'], hue='Income', data= Census_pro)
plt.xlabel('Occupation', fontsize=15)
plt.xticks(rotation = 80)
plt.ylabel('Hours_per_week', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see for same occupation if a person workign extra per week. He is getting extra pay.
#
# Thats why as the workign hours increases , chance to get income >=50K is higher.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Lets first drop the unnecessary columns from dataset.
#
# We will drop Capital_gain, Capital_loss and Fnlwgt as they are not relevent.

# %%
Census_pro.drop(['Fnlwgt','Capital_gain', 'Capital_loss'], axis=True, inplace= True)

# %%
Census_pro
# Out:
#        Age          Workclass    Education  Education_num  \
# 0       50   Self-emp-not-inc    Bachelors             13
# 1       38            Private      HS-grad              9
# 2       53            Private         11th              7
# 3       28            Private    Bachelors             13
# 4       37            Private      Masters             14
# ...    ...                ...          ...            ...
# 32555   27            Private   Assoc-acdm             12
# 32556   40            Private      HS-grad              9
# 32557   58            Private      HS-grad              9
# 32558   22            Private      HS-grad              9
# 32559   52       Self-emp-inc      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
#Shape of the dataset after removing columns

Census_pro.shape
# Out:
# (30161, 12)

# %%
Indepnedent_features=Census_pro.drop(['Income','Education'], axis=1)
Target_features= Census_pro['Income']

# %%
Census_new= pd.get_dummies(Indepnedent_features,sparse=False, drop_first=True )

# %%
Census_new
# Out:
#        Age  Education_num  Hours_per_week  Workclass_ Local-gov  \
# 0       50             13              13                     0
# 1       38              9              40                     0
# 2       53              7              40                     0
# 3       28             13              40                     0
# 4       37             14              40                     0
# ...    ...            ...             ...                   ...
# 32555   27             12              38                     0
# 32556   40              9              40                     0
# 32557   58              9              40                     0
# 32558   22              9              20                     0
# 32559   52              9              40                     0
#
#        Workclass_ Private  Workclass_ Self-emp-inc  \
# 0                       0                        0
# 1                       1                        0
# ...

# %%
#Shape of the dataset

Census_new.shape
# Out:
# (30161, 78)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
Census_new['Education']=le.fit_transform(Census_pro['Education'])

# %%
Census_new['Income']= Target_features

# %%
Census_new.head()
# Out:
#    Age  Education_num  Hours_per_week  Workclass_ Local-gov  \
# 0   50             13              13                     0
# 1   38              9              40                     0
# 2   53              7              40                     0
# 3   28             13              40                     0
# 4   37             14              40                     0
#
#    Workclass_ Private  Workclass_ Self-emp-inc  Workclass_ Self-emp-not-inc  \
# 0                   0                        0                            1
# 1                   1                        0                            0
# 2                   1                        0                            0
# 3                   1                        0                            0
# 4                   1                        0                            0
#
#    Workclass_ State-gov  Workclass_ Without-pay  \
# 0                     0                       0
# ...

# %% [markdown]
# # Let's check correlation

# %%
Census_new.corr()
# Out:
#                                     Age  Education_num  Hours_per_week  \
# Age                            1.000000       0.043525        0.101599
# Education_num                  0.043525       1.000000        0.152528
# Hours_per_week                 0.101599       0.152528        1.000000
# Workclass_ Local-gov           0.068257       0.097390        0.001611
# Workclass_ Private            -0.210498      -0.165017       -0.095542
# ...                                 ...            ...             ...
# Native_country_ United-States  0.016259       0.127199        0.010674
# Native_country_ Vietnam       -0.017775      -0.010952       -0.010381
# Native_country_ Yugoslavia     0.000657      -0.001660        0.006983
# Education                     -0.001111       0.345431        0.059887
# Income                         0.242000       0.335317        0.229480
#
#                                Workclass_ Local-gov  Workclass_ Private  \
# ...

# %%
plt.figure(figsize=(20,35))
Census_new.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='barh',color='c')
plt.xlabel('Feature', fontsize=14)
plt.ylabel('Columns with target name', fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# Here we can see in the graphs , Native country hungry having 0 correlation with the income,
# Columns on the left of 0.0  are positive correlated , on the other hand values on the left of the 0.0 are negative correlated.

# %% [markdown]
# ## Checking Skewness

# %% [markdown]
# Most of the columns are categorical, we will remove skewness from few columns only.

# %%
Census_new.skew()
# Out:
# Age                               0.530223
# Education_num                    -0.305328
# Hours_per_week                    0.330856
# Workclass_ Local-gov              3.415613
# Workclass_ Private               -1.087863
#                                    ...
# Native_country_ United-States    -2.905983
# Native_country_ Vietnam          21.640571
# Native_country_ Yugoslavia       43.384908
# Education                        -0.944971
# Income                            1.161357
# Length: 80, dtype: float64

# %% [markdown]
# Age, Education_num, Hours_per_week  are not having skewness we can proceed further.

# %% [markdown]
# ## Scaling the data Using StandardScaler.

# %%
# Dividing into Feature and Target data
x=Census_new.drop(['Income'],axis=1)
y=Census_new['Income']

# %%
from sklearn.preprocessing import StandardScaler

# %%
SDC=StandardScaler()
x=SDC.fit_transform(x)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# ### Here we can see our output is not balanced we will now use SMOTE to balance the output.

# %%
#import smote from imblearn

from imblearn.over_sampling import SMOTE
X_train_over, Y_train_over =SMOTE(k_neighbors=3).fit_resample(x,y)

# %%
X_train_over.shape
# Out:
# (45306, 79)

# %%
Y_train_over.value_counts()
# Out:
# 0    22653
# 1    22653
# Name: Income, dtype: int64

# %%
Census_new.columns
# Out:
# Index(['Age', 'Education_num', 'Hours_per_week', 'Workclass_ Local-gov',
#        'Workclass_ Private', 'Workclass_ Self-emp-inc',
#        'Workclass_ Self-emp-not-inc', 'Workclass_ State-gov',
#        'Workclass_ Without-pay', 'Marital_status_ Married-AF-spouse',
#        'Marital_status_ Married-civ-spouse',
#        'Marital_status_ Married-spouse-absent',
#        'Marital_status_ Never-married', 'Marital_status_ Separated',
#        'Marital_status_ Widowed', 'Occupation_ Armed-Forces',
#        'Occupation_ Craft-repair', 'Occupation_ Exec-managerial',
#        'Occupation_ Farming-fishing', 'Occupation_ Handlers-cleaners',
#        'Occupation_ Machine-op-inspct', 'Occupation_ Other-service',
#        'Occupation_ Priv-house-serv', 'Occupation_ Prof-specialty',
#        'Occupation_ Protective-serv', 'Occupation_ Sales',
#        'Occupation_ Tech-support', 'Occupation_ Transport-moving',
#        'Relationship_ Not-in-family', 'Relationship_ Other-relative',
# ...

# %% [markdown]
# # Creating train_test_split

# %%
#Import train test split from sklearn(Model selection)

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, random_state=42, test_size=.33)

print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (20207, 79)
# Training target vector size: (20207,)
# Test feature matrix size: (9954, 79)
# Test target vector size: (9954,)

# %% [markdown]
# ## Machine learning model building

# %%
#Import necessary libraries

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Lasso, Ridge


# sklearn modules for performance metrics

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Chosing Best Random State

# %%
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
y_pred=log_reg.predict(x_test)


print('\033[1m','Logistics Regression Evaluation','\033[0m','\n')

print('Accuracy Score of Logistics Regression :','\n', accuracy_score(y_test, y_pred))
print('\n')
print('Confusion matrix of Logistics Regression :','\n',confusion_matrix(y_test, y_pred))
print('\n')
print('Classification Report of Logistics Regression','\n',classification_report(y_test, y_pred))
# Out:
#  Logistics Regression Evaluation
#
# Accuracy Score of Logistics Regression :
#  0.8333333333333334
#
#
# Confusion matrix of Logistics Regression :
#  [[6892  632]
#  [1027 1403]]
#
#
# Classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      7524
#            1       0.69      0.58      0.63      2430
#
#     accuracy                           0.83      9954
#    macro avg       0.78      0.75      0.76      9954
# weighted avg       0.83      0.83      0.83      9954

# %% [markdown]
# ## Cross validation score from Logistic Regression

# %%
from sklearn.model_selection import cross_val_score

# %%
#Logistic regression

score = cross_val_score(log_reg,x,y)

print('\033[1m','Cross Validation score of Logistics Regression is :','\033[0m','\n')
print('Score :',score)
print('Mean Score :', score.mean())
print('Standard Deviation :',score.std())
# Out:
#  Cross Validation score of Logistics Regression is :
#
# Score : [0.83026687 0.82344164 0.8323939  0.84068302 0.83305703]
# Mean Score : 0.831968492477932
# Standard Deviation : 0.005530128569210746

# %% [markdown]
# # Now applying other classification algorithm and plotting ROC curve

# %%
RFC = RandomForestClassifier()
SVM = SVC()
KNN = KNeighborsClassifier()
DTC = DecisionTreeClassifier()
ABC = AdaBoostClassifier()
GBC = GradientBoostingClassifier()

model = [RFC, SVM, KNN, DTC, ABC, GBC]
       
        
for m in model:
    m.fit(x_train,y_train)
    y_pred=m.predict(x_test)
    
    print('\033[1m','Classification Machine Learning Algorithm Evaluation Matrix',m,'is','\033[0m','\n')
    
    print('Accuracy Score :','\n', accuracy_score(y_test, y_pred),'\n')
    
    print('Confusion matrix :','\n',confusion_matrix(y_test, y_pred),'\n')

    print('Classification Report :','\n',classification_report(y_test, y_pred),'\n')
    
    print('='*100)
# Out:
#  Classification Machine Learning Algorithm Evaluation Matrix RandomForestClassifier() is
#
# Accuracy Score :
#  0.8138436809322885
#
# Confusion matrix :
#  [[6714  810]
#  [1043 1387]]
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      7524
#            1       0.63      0.57      0.60      2430
#
#     accuracy                           0.81      9954
#    macro avg       0.75      0.73      0.74      9954
# weighted avg       0.81      0.81      0.81      9954
#
#
# ...
#  Classification Machine Learning Algorithm Evaluation Matrix SVC() is
#
# Accuracy Score :
#  0.8319268635724332
#
# Confusion matrix :
#  [[6969  555]
#  [1118 1312]]
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89      7524
#            1       0.70      0.54      0.61      2430
#
#     accuracy                           0.83      9954
# ...

# %% [markdown]
# ## Now applying cross validation on above algorithms

# %%
#Cross Validation

model = [RFC, SVM, KNN, DTC, ABC, GBC]

for i in model:
    score = cross_val_score(i, x, y, cv =5)
    print('\n')
    print('\033[1m','Cross Validation score',i,'is','\033[0m','\n')
    print('Score :',score)
    print('Mean Score :', score.mean())
    print('Standard Deviation :',score.std())
    print('='*80)
# Out:
#  Cross Validation score RandomForestClassifier() is
#
# Score : [0.81617769 0.80802387 0.81200265 0.82228117 0.81266578]
# Mean Score : 0.8142302328352329
# Standard Deviation : 0.004786202147276928
# ...
#
#
#  Cross Validation score SVC() is
#
# Score : [0.82628875 0.82393899 0.8219496  0.83255968 0.82675729]
# Mean Score : 0.8262988631052641
# Standard Deviation : 0.003574721629173254
# ...
#
#
#  Cross Validation score KNeighborsClassifier() is
#
# Score : [0.8083872  0.81100796 0.81498674 0.8153183  0.81432361]
# Mean Score : 0.8128047616974896
# Standard Deviation : 0.0026880893130548874
# ...
#
#
#  Cross Validation score DecisionTreeClassifier() is
#
# Score : [0.76877176 0.77635942 0.77901194 0.78464854 0.7793435 ]
# Mean Score : 0.7776270301142126
# Standard Deviation : 0.005180513315031257
# ...
#
#
#  Cross Validation score AdaBoostClassifier() is
#
# Score : [0.83059838 0.82526525 0.83421751 0.83985411 0.83554377]
# Mean Score : 0.8330958024411274
# Standard Deviation : 0.004908770721250368
# ...
#
# ...

# %% [markdown]
# __WE can see here in all models Accuracy score but GradientBoostingClassifier() gives us good accuracy score of 0. 0.8364, So now we will perform Hyper Parameter Tuning on GradientBoostingClassifier()__

# %% [markdown]
# # Hyperparameter Tuning

# %%
#Import library

from sklearn.model_selection import GridSearchCV

# %%
parameters = {'learning_rate': [0.01,0.02,0.03],
              'subsample'    : [0.9, 0.5, 0.2],
              'n_estimators' : [100,500,1000],
              'max_depth'    : [4,6,8]}

# %%
grid_GBC = GridSearchCV(GradientBoostingClassifier(), param_grid = parameters, cv = 2, n_jobs=-1)

# %%
grid_GBC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.02, 0.03],
#                          'max_depth': [4, 6, 8],
#                          'n_estimators': [100, 500, 1000],
#                          'subsample': [0.9, 0.5, 0.2]})

# %%
grid_GBC.best_params_
# Out:
# {'learning_rate': 0.02, 'max_depth': 4, 'n_estimators': 500, 'subsample': 0.9}

# %% [markdown]
# ## Final model

# %%
Final_mod = GradientBoostingClassifier(n_estimators= 500)
Final_mod.fit(x_train,y_train)
y_pred=Final_mod.predict(x_test)
print('Accuracy Score :','\n', accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score :
#  0.8372513562386981

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

y_pred_prob = Final_mod.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test,y_pred_prob)

plt.plot([0,1],[0,1], 'k--')

plt.plot(fpr, tpr, label='Random Forest Classifier')
plt.xlabel('False postive rate')
plt.ylabel('True postive rate')
plt.show()
auc_score = roc_auc_score(y_test, Final_mod.predict(x_test))
print('Auc Score :','\n',auc_score)
# Out:
# Auc Score :
#  0.7573557209522122

# %% [markdown]
# ### Saving Best Model

# %%
import joblib
joblib.dump(Final_mod,'')
# Out:
# ['Census_Income_Project.pkl']
