# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Create dataframe and read csv file from github

# %%
Global_ppdp = pd.read_csv("https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv")
Global_ppdp.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
#Shape of dataset

Global_ppdp.shape
# Out:
# (907, 27)

# %% [markdown]
# __Here 907 rows and 27 columns present in dataset__

# %%
#Checking columns name from dataset

Global_ppdp.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# __Key attributes of the database__
# The database includes the following indicators:
#
# • `country (text)`:     3 character country code corresponding to the ISO 3166-1 alpha-3 specification.
#
# • `country_long (text)`:     longer form of the country designation
#
# • `name (text)`:     name or title of the power plant, generally in Romanized form
#
# • `gppd_idnr (text)`:     10 or 12 character identifier for the power plant
#
# • `capacity_mw (number)`:     electrical generating capacity in megawatts
#
# • `latitude (number)`:     geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# • `longitude (number)`:     geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# • `primary_fuel (text)`:     energy source used in primary electricity generation or export
#
# • `other_fuel1 (text)`:     energy source used in electricity generation or export
#
# • `other_fuel2 (text)`:     energy source used in electricity generation or export
#
# • `other_fuel3 (text)`:     energy source used in electricity generation or export
#
# • `commissioning_year (number)`:     year of plant operation, weighted by unit-capacity when data is available
#
# • `owner (text)`:     majority shareholder of the power plant, generally in Romanized form
#
# • `source (text)`:     entity reporting the data; could be an organization, report, or document, generally in Romanized form
#
# • `url (text)`:     web document corresponding to the source field
#
# • `geolocation_source (text)`:     attribution for geolocation information
#
# • `wepp_id (text)`:     a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#
# • `year_of_capacity_data (number)`:     year the capacity information was reported
#
# • `generation_gwh_2013 (number)`:     electricity generation in gigawatt-hours reported for the year 2013
#
# • `generation_gwh_2014 (number)`:     electricity generation in gigawatt-hours reported for the year 2014
#
# • `generation_gwh_2015 (number)`:     electricity generation in gigawatt-hours reported for the year 2015
#
# • `generation_gwh_2016 (number)`:     electricity generation in gigawatt-hours reported for the year 2016
#
# • `generation_gwh_2017 (number)`:     electricity generation in gigawatt-hours reported for the year 2017
#
# • `generation_gwh_2018 (number)`:     electricity generation in gigawatt-hours reported for the year 2018
#
# • `generation_gwh_2019 (number)`:     electricity generation in gigawatt-hours reported for the year 2019
#
# • `generation_data_source (text)`:    attribution for the reported generation information
#
# • `estimated_generation_gwh_2013 (number)`:     estimated electricity generation in gigawatt-hours for the year 2013
#
# • `estimated_generation_gwh_2014 (number)`:     estimated electricity generation in gigawatt-hours for the year 2014
#
# • `estimated_generation_gwh_2015 (number)`:     estimated electricity generation in gigawatt-hours for the year 2015
#
# • `estimated_generation_gwh_2016 (number)`:     estimated electricity generation in gigawatt-hours for the year 2016
#
# • `estimated_generation_gwh_2017 (number)`:     estimated electricity generation in gigawatt-hours for the year 2017
#
# • `estimated_generation_note_2013 (text)`:     label of the model/method used to estimate generation for the year 2013
#
# • `estimated_generation_note_2014 (text)`:     label of the model/method used to estimate generation for the year 2014
#
# • `estimated_generation_note_2015 (text)`:     label of the model/method used to estimate generation for the year 2015
#
# • `estimated_generation_note_2016 (text)`:     label of the model/method used to estimate generation for the year 2016
#
# • `estimated_generation_note_2017 (text)`:     label of the model/method used to estimate generation for the year 2017

# %%
#Dataset information

Global_ppdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# __Here we have out of 25, 15 columns are float type and 12 object data type columns.__
#
# __Data is having missing values also in many columns.__

# %%
#Checking null values

Global_ppdp.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
#     Here we can see most of the columns are having missing values
#     19 out of 27 columns contains missing value
#     latitude and longitude columns have same (46) missing values
#     other_fuel1, other_fuel2 and other_fuel3 are having large number of missing values

# %%
#Plotiing heatmap from null values

plt.figure(figsize=(18,10))
sns.heatmap(Global_ppdp.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Now separating numerical and categorical column from dataset

# %%
#Checking for categorical columnn

categorical_col=[]

for i in Global_ppdp.dtypes.index:
    if Global_ppdp.dtypes[i] == 'object':
        categorical_col.append(i)
print('Categorical Columns: ', categorical_col)
print('\n')


#checking for numerical columns
numerical_col=[]

for i in Global_ppdp.dtypes.index:
    if Global_ppdp.dtypes[i] != 'object':
        numerical_col.append(i)
print('Numerical Columns: ', numerical_col)
# Out:
# Categorical Columns:  ['country', 'country_long', 'name', 'gppd_idnr', 'primary_fuel', 'other_fuel1', 'other_fuel2', 'owner', 'source', 'url', 'geolocation_source', 'generation_data_source']
#
#
# Numerical Columns:  ['capacity_mw', 'latitude', 'longitude', 'other_fuel3', 'commissioning_year', 'wepp_id', 'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', 'generation_gwh_2019', 'estimated_generation_gwh']

# %%
#Statistical summary of the dataset

Global_ppdp.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %% [markdown]
# ### Dropping all unnecessary columns from dataset

# %%
Global_ppdp['country'].value_counts()
# Out:
# IND    907
# Name: country, dtype: int64

# %% [markdown]
#     country, country_long are just the name, and here we have data only for india.
#     other_fuel1,other_fuel2, other_fuel3 are also having many Nan values, so we will drop them.
#     wepp_id, generation_data_source, estimated_generation_gwh are also having so many Nan values, so we will drope them also.
#     year_of_capacity_data column also having missing values, so we will also drop this column.
#     url have no missing value but this column is not important so will drop this column also.

# %%
Global_ppdp.drop(['country','country_long','other_fuel1','other_fuel2', 'other_fuel3','wepp_id', 'generation_data_source',
                  'estimated_generation_gwh', 'year_of_capacity_data','url', 'geolocation_source'],inplace = True, axis = 1)
Global_ppdp.head()
# Out:
#                        name   gppd_idnr  capacity_mw  latitude  longitude  \
# 0          ACME Solar Tower  WRI1020239          2.5   28.1839    73.2407
# 1       ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663    74.6090
# 2  AES Saurashtra Windfarms  WRI1026669         39.2   21.9038    69.3732
# 3               AGARTALA GT  IND0000001        135.0   23.8712    91.3602
# 4              AKALTARA TPP  IND0000002       1800.0   21.9603    82.4091
#
#   primary_fuel  commissioning_year                 owner  \
# 0        Solar              2011.0           Solar Paces
# 1         Coal                 NaN  Ultratech Cement ltd
# 2         Wind                 NaN                   AES
# 3          Gas              2004.0                   NaN
# 4         Coal              2015.0                   NaN
#
#                                  source  generation_gwh_2013  \
# 0  National Renewable Energy Laboratory                  NaN
# ...

# %%
Global_ppdp.head(2)
# Out:
#                   name   gppd_idnr  capacity_mw  latitude  longitude  \
# 0     ACME Solar Tower  WRI1020239          2.5   28.1839    73.2407
# 1  ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663    74.6090
#
#   primary_fuel  commissioning_year                 owner  \
# 0        Solar              2011.0           Solar Paces
# 1         Coal                 NaN  Ultratech Cement ltd
#
#                                  source  generation_gwh_2013  \
# 0  National Renewable Energy Laboratory                  NaN
# 1                  Ultratech Cement ltd                  NaN
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
#
#    generation_gwh_2017  generation_gwh_2018  generation_gwh_2019
# 0                  NaN                  NaN                  NaN
# ...

# %%
#Shape of the dataset after removing unnecessary columns

Global_ppdp.shape
# Out:
# (907, 16)

# %% [markdown]
# ## Filling null values from median method

# %%
Global_ppdp['generation_gwh_2013'].fillna(value=Global_ppdp['generation_gwh_2013'].median(), inplace= True)
Global_ppdp['generation_gwh_2014'].fillna(value=Global_ppdp['generation_gwh_2014'].median(), inplace= True)
Global_ppdp['generation_gwh_2015'].fillna(value=Global_ppdp['generation_gwh_2015'].median(), inplace= True)
Global_ppdp['generation_gwh_2016'].fillna(value=Global_ppdp['generation_gwh_2016'].median(), inplace= True)
Global_ppdp['generation_gwh_2017'].fillna(value=Global_ppdp['generation_gwh_2017'].median(), inplace= True)
Global_ppdp['generation_gwh_2018'].fillna(value=Global_ppdp['generation_gwh_2018'].median(), inplace= True)
Global_ppdp['generation_gwh_2019'].fillna(value=Global_ppdp['generation_gwh_2019'].median(), inplace= True)

# %% [markdown]
# This columns are so many null values so we will use median method to fill missing values

# %% [markdown]
# ## Filling null values from mean method

# %%
Global_ppdp['latitude'].fillna(value=Global_ppdp['latitude'].mean(), inplace= True)
Global_ppdp['longitude'].fillna(value=Global_ppdp['longitude'].mean(), inplace= True)

# %% [markdown]
# This columns have same null values so will will use mean method to fill missing values

# %%
Global_ppdp.isnull().sum()
# Out:
# name                     0
# gppd_idnr                0
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year     380
# owner                  565
# source                   0
# generation_gwh_2013    907
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# generation_gwh_2019    907
# dtype: int64

# %% [markdown]
# # Lets plot the countplot and value counts for targat and feature columns.
#
# ### Target columns -  'primary_fuel' and 'capacity_mw'

# %%
#plotting countplot
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,8))
sns.countplot(Global_ppdp['primary_fuel'] )
plt.xlabel('Count', fontsize=15 )
plt.ylabel('primary_fuel', fontsize=15 )
plt.title('primary_fuel', fontsize=15)

#print value counts
Global_ppdp['primary_fuel'].value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
#     Here we can see most of the power plants are use using Coal and Hydro as the primary fuel.
#     Coal having maximum counts, which indicates most of the power generation plant using coal as primary fuel.
#     Few power generation plant using oil and nuclear as primary fuel.
#     Solar and wind also use as primary fuel in power generarion plant.

# %%
#plotting countplot
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,5))

sns.distplot(Global_ppdp['capacity_mw'] )
plt.ylabel('capacity_mw', fontsize=15 )
plt.title('capacity_mw', fontsize=15)

#print value counts
Global_ppdp['capacity_mw'].value_counts()
# Out:
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64

# %% [markdown]
#     Here we will see data is not normaly distributed.
#     Data having outliers.

# %% [markdown]
# ## Plotting countplot in commissioning_year

# %%
#Plotting countplot
sns.set_theme(style='whitegrid')
plt.figure(figsize=(20,5))

sns.countplot(Global_ppdp['commissioning_year'])
plt.xlabel('Commissioning Year', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(fontsize=12, rotation=75)

#print value counts
Global_ppdp['commissioning_year'].value_counts()
# Out:
# 2015.0    28
# 2013.0    25
# 2012.0    23
# 2016.0    19
# 2010.0    18
#           ..
# 1946.0     1
# 1956.0     1
# 1937.0     1
# 1949.0     1
# 1953.0     1
# Name: commissioning_year, Length: 73, dtype: int64

# %% [markdown]
#     Here we can see first power generation plant in India starts in 1927.
#     From 1957 to 1983 there is contineous developmet of 3 to 5 power plant every year.
#     In the year 2015 we have maximum number of Power plant, the count is more than 25.

# %% [markdown]
# ## Value counts from owner column

# %%
#print value counts
Global_ppdp['owner'].value_counts()
# Out:
# Acc Acc ltd                                                    4
# Sterling Agro Industries ltd.                                  4
# Jk Cement ltd                                                  4
# SWPPL                                                          3
# Jaypee Ltd jccl)                                               3
#                                                               ..
# Sunkon Energy Private Limited                                  1
# West Bengal Energy Development Corporation Limited (WBEDCL)    1
# Energy Infratech Private Limited                               1
# K. N. Ram                                                      1
# iEnergy Wind Farms                                             1
# Name: owner, Length: 280, dtype: int64

# %% [markdown]
#     Here many Company having power plant, so we dont plotting count plot.
#     We can see Acc Acc lTD, Sterling Agro Industries ltd and JK Cement lTD having maximum number (4) of power plants.
#     Other company having 3,2 or only single power plant.

# %% [markdown]
# ## Now checking correlation between numerical column

# %%
Global_ppdp.corr()
# Out:
#                      capacity_mw  latitude  longitude  commissioning_year  \
# capacity_mw             1.000000  0.050984   0.195882            0.304087
# latitude                0.050984  1.000000   0.036362            0.124504
# longitude               0.195882  0.036362   1.000000            0.115182
# commissioning_year      0.304087  0.124504   0.115182            1.000000
# generation_gwh_2013          NaN       NaN        NaN                 NaN
# generation_gwh_2014     0.793497  0.058594   0.104649            0.112889
# generation_gwh_2015     0.819676  0.053869   0.121513            0.147515
# generation_gwh_2016     0.853008  0.047677   0.143459            0.182283
# generation_gwh_2017     0.868338  0.057897   0.151712            0.195345
# generation_gwh_2018     0.884840  0.055216   0.155063            0.201070
# generation_gwh_2019          NaN       NaN        NaN                 NaN
#
#                      generation_gwh_2013  generation_gwh_2014  \
# ...

# %%
#Visualize correlation by plotting heatmap

plt.figure(figsize=(10,10))
sns.heatmap(Global_ppdp.corr(), annot = True, linewidth= 0.2, linecolor = 'black', cmap = 'coolwarm')
plt.show()

# %% [markdown]
# We can see generation_gwh_2013 and generation_gwh_2019 are correlation with all columns but both columns having maximum null values so we will seen blank space in above figure.

# %% [markdown]
# ## Distribution of features

# %%
Numerical = ['capacity_mw', 'latitude', 'longitude','commissioning_year', 'generation_gwh_2013', 'generation_gwh_2014',
             'generation_gwh_2015','generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', 'generation_gwh_2019']

# %% [markdown]
# ## Visualize distplot from columns

# %%
#Let's visualize distplot from columns

plt.figure(figsize=(20,25), facecolor='white')
plotnumber =1

for column in Numerical:
    if plotnumber <=15:
        ax = plt.subplot(5,3,plotnumber)
        sns.distplot(Global_ppdp[column], color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
    
plt.show()

# %% [markdown]
#     From the above distributionplot we can observe that the data is not normally distributed in all the columns except latitude and longitude.
#     In most of the columns the mean is greater than the median which means they are skewed to right.
#     We will remove the skewness in all these columns except the label later.

# %% [markdown]
# __Here we can see, name, gppd_idnr, owner, commissioning_year are not playing good role, we can drop these columns.__
#
# __generation_gwh_2013, generation_gwh_2019 and source are also is not playing good role, so we can also drom them columns.__

# %% [markdown]
# ### Let's drop those columns

# %%
Global_ppdp.drop(['name','gppd_idnr','owner','commissioning_year','generation_gwh_2013', 'generation_gwh_2019','source'], axis=1, inplace= True)
Global_ppdp.head(2)
# Out:
#    capacity_mw  latitude  longitude primary_fuel  generation_gwh_2014  \
# 0          2.5   28.1839    73.2407        Solar           801.123775
# 1         98.0   24.7663    74.6090         Coal           801.123775
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0           711.181225            737.20545            817.97725
# 1           711.181225            737.20545            817.97725
#
#    generation_gwh_2018
# 0           751.644375
# 1           751.644375

# %% [markdown]
# ## Visualize sctterplot and Comparision between target variable ( capacity_mw ) and dependent variable

# %%
#Generation_gwh_2014 vs capacity_mw

plt.figure(figsize=(18,7))
sns.scatterplot(data=Global_ppdp, x='generation_gwh_2014',y='capacity_mw')
plt.title('generation_gwh_2014 vs capacity_mw ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# with higher capacity, generation_gwh_2014 also incresing.

# %%
#Generation_gwh_2015 vs capacity_mw

plt.figure(figsize=(18,7))
sns.scatterplot(data=Global_ppdp, x='generation_gwh_2015',y='capacity_mw')
plt.title('generation_gwh_2015 vs capacity_mw ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# with higher capacity, generation_gwh_2015 also incresing.

# %%
#Generation_gwh_2016 vs capacity_mw

plt.figure(figsize=(18,7))
sns.scatterplot(data=Global_ppdp, x='generation_gwh_2016',y='capacity_mw')
plt.title('generation_gwh_2016 vs capacity_mw ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# with higher capacity, generation_gwh_2016 also incresing.

# %%
#Generation_gwh_2017 vs capacity_mw

plt.figure(figsize=(18,7))
sns.scatterplot(data=Global_ppdp, x='generation_gwh_2017',y='capacity_mw')
plt.title('generation_gwh_2017 vs capacity_mw ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# with higher capacity, generation_gwh_2017 also incresing.

# %%
#Generation_gwh_2018 vs capacity_mw

plt.figure(figsize=(18,7))
sns.scatterplot(data=Global_ppdp, x='generation_gwh_2018',y='capacity_mw')
plt.title('generation_gwh_2018 vs capacity_mw ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# with higher capacity, generation_gwh_2018 also incresing.

# %% [markdown]
# ## Visualize lineplot and Comparision between target variable ( primary_fuel ) and dependent variable

# %%
#Primary_fuel vs Generation_gwh_2014

plt.figure(figsize=(18,7))
sns.set_theme(style='darkgrid')
sns.lineplot(data=Global_ppdp, x='primary_fuel',y='generation_gwh_2014')
plt.title('Primary fuel vc Generation gwh 2014 ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# We can see coal is the primary fuel for power generation.

# %%
#Primary_fuel vs Generation_gwh_2015

plt.figure(figsize=(18,7))
sns.lineplot(data=Global_ppdp, x='primary_fuel',y='generation_gwh_2015')
plt.title('Primary fuel vc Generation gwh 2015 ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# We can see coal is the primary fuel for power generation.

# %%
#Primary_fuel vs Generation_gwh_2016

plt.figure(figsize=(18,7))
sns.lineplot(data=Global_ppdp, x='primary_fuel',y='generation_gwh_2016')
plt.title('Primary fuel vc Generation gwh 2016 ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# We can see coal is the primary fuel for power generation.

# %%
#Primary_fuel vs Generation_gwh_2017

plt.figure(figsize=(18,7))
sns.lineplot(data=Global_ppdp, x='primary_fuel',y='generation_gwh_2017')
plt.title('Primary fuel vc Generation gwh 2017 ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# We can see coal is the primary fuel for power generation.

# %%
#Primary_fuel vs Generation_gwh_2018

plt.figure(figsize=(18,7))
sns.lineplot(data=Global_ppdp, x='primary_fuel',y='generation_gwh_2018')
plt.title('Primary fuel vc Generation gwh 2018 ', fontsize=22)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# We can see coal is the primary fuel for power generation.

# %% [markdown]
# # Let's visualize scatterplot and comparison between both target variable

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=Global_ppdp, x='primary_fuel',y='capacity_mw')
plt.title('primary_fuel vs capacity_mw ', fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# We can see most of the power capacity is due to coal.

# %% [markdown]
# ## Visualize pairplot

# %%
sns.pairplot(Global_ppdp)

# %% [markdown]
#     capacity_mw: we can see capacity is mostly dependent on Coal.
#     primary_fuel: Mostly Coal is used as primary fuel.
#     latitude & longitude : They are not playing very good role in capacity_mw.
#     generation_gwh_2014-2018: we can see generation growth is almost same for each year

# %% [markdown]
# ## Now encoding Target columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Global_ppdp['primary_fuel']=le.fit_transform(Global_ppdp['primary_fuel'])

# %%
Global_ppdp.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  generation_gwh_2014  \
# 0          2.5   28.1839    73.2407             6           801.123775
# 1         98.0   24.7663    74.6090             1           801.123775
# 2         39.2   21.9038    69.3732             7           801.123775
# 3        135.0   23.8712    91.3602             2           617.789264
# 4       1800.0   21.9603    82.4091             1          3035.550000
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0           711.181225           737.205450           817.977250
# 1           711.181225           737.205450           817.977250
# 2           711.181225           737.205450           817.977250
# 3           843.747000           886.004428           663.774500
# 4          5916.370000          6243.000000          5385.579736
#
#    generation_gwh_2018
# 0           751.644375
# 1           751.644375
# 2           751.644375
# 3           626.239128
# 4          7279.000000

# %% [markdown]
# ## Now again check correlation and plotting heatmap

# %%
Global_ppdp.corr()
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.050984   0.195882     -0.380395
# latitude                0.050984  1.000000   0.036362     -0.010204
# longitude               0.195882  0.036362   1.000000     -0.347948
# primary_fuel           -0.380395 -0.010204  -0.347948      1.000000
# generation_gwh_2014     0.793497  0.058594   0.104649     -0.240656
# generation_gwh_2015     0.819676  0.053869   0.121513     -0.249304
# generation_gwh_2016     0.853008  0.047677   0.143459     -0.259708
# generation_gwh_2017     0.868338  0.057897   0.151712     -0.263599
# generation_gwh_2018     0.884840  0.055216   0.155063     -0.271198
#
#                      generation_gwh_2014  generation_gwh_2015  \
# capacity_mw                     0.793497             0.819676
# latitude                        0.058594             0.053869
# longitude                       0.104649             0.121513
# ...

# %%
plt.figure(figsize=(20,10))

sns.heatmap(Global_ppdp.corr(),annot= True,linewidths=1,linecolor='black',fmt=' .2f' )
# Out:
# <AxesSubplot:>

# %%
#Correlation between Capacity and features variable

plt.figure(figsize=(20,7))
Global_ppdp.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Capacity',fontsize=15)
plt.title('Correlation between capacity and features using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# Here we can see only primary fuel is negative correlated with capacity megawatt, all othere parameters are having strong positve correlation.

# %%
#Correlation between Primary fuel and features variable

plt.figure(figsize=(20,7))
Global_ppdp.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Capacity',fontsize=15)
plt.title('Correlation between primary_fuel and features using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# Here we can see only primary fuel is strong positive correlated with capacity megawatt, all othere parameters are having negative correlation.

# %% [markdown]
# ## Checking outliers

# %%
#Let's check the outliers by plotting boxplot.

Global_ppdp.plot(kind='box', subplots=True, layout=(3,3),figsize=(20,20));

# %% [markdown]
#     'latitude' and 'primary_fuel' have no outliers.
#     Many outliers present in 'capacity_mw', 'longitude', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018' columns.

# %% [markdown]
# ## Removing outliers

# %%
from scipy.stats import zscore

z = np.abs(zscore(Global_ppdp))

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([ 15,  15,  15,  15,  15, 143, 143, 143, 143, 143, 143, 147, 158,
#        179, 183, 209, 209, 209, 209, 209, 209, 244, 308, 308, 308, 308,
#        308, 308, 323, 333, 340, 360, 363, 364, 364, 364, 364, 364, 364,
#        375, 416, 427, 482, 482, 493, 493, 493, 493, 493, 493, 494, 494,
#        494, 494, 494, 494, 499, 519, 532, 546, 577, 623, 638, 648, 648,
#        648, 648, 648, 648, 657, 657, 657, 657, 657, 657, 695, 695, 695,
#        695, 695, 695, 721, 721, 721, 721, 721, 724, 724, 724, 724, 724,
#        726, 726, 726, 726, 726, 726, 767, 786, 786, 786, 786, 786, 786,
#        788, 808, 808, 808, 808, 808, 808, 818, 847, 880, 880, 880, 880,
#        880, 880], dtype=int64), array([0, 5, 6, 7, 8, 0, 4, 5, 6, 7, 8, 0, 4, 2, 2, 0, 4, 5, 6, 7, 8, 2,
#        0, 4, 5, 6, 7, 8, 2, 2, 2, 2, 0, 0, 4, 5, 6, 7, 8, 0, 2, 2, 0, 8,
#        0, 4, 5, 6, 7, 8, 0, 4, 5, 6, 7, 8, 2, 2, 4, 2, 2, 4, 2, 0, 4, 5,
#        6, 7, 8, 0, 4, 5, 6, 7, 8, 0, 4, 5, 6, 7, 8, 4, 5, 6, 7, 8, 4, 5,
# ...

# %%
Global_ppdp1 = Global_ppdp[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", Global_ppdp.shape)
print ("Shape of the dataframe after removing outliers: ", Global_ppdp1.shape)
print ("Percentage of data loss post outlier removal: ", (Global_ppdp.shape[0]-Global_ppdp1.shape[0])/Global_ppdp.shape[0]*100)
# Out:
# Shape of the dataframe before removing outliers:  (907, 9)
# Shape of the dataframe after removing outliers:  (866, 9)
# Percentage of data loss post outlier removal:  4.5203969128996695

# %% [markdown]
# # Checking Skewness

# %%
Global_ppdp.skew()
# Out:
# capacity_mw            3.123576
# latitude              -0.149698
# longitude              1.141881
# primary_fuel           0.472251
# generation_gwh_2014    5.321360
# generation_gwh_2015    5.566773
# generation_gwh_2016    5.281953
# generation_gwh_2017    5.315103
# generation_gwh_2018    5.133226
# dtype: float64

# %% [markdown]
# ## Removing skewness using yeo-johnson method

# %%
# Removing skewness using yeo-johnson  method to get better prediction
skew = ['capacity_mw','longitude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017',
        'generation_gwh_2018']

from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

Global_ppdp[skew] = scaler.fit_transform(Global_ppdp[skew].values)
Global_ppdp[skew].head()
# Out:
#    capacity_mw  longitude  generation_gwh_2014  generation_gwh_2015  \
# 0    -1.695767  -0.952545            -0.046742            -0.052449
# 1     0.193694  -0.544976            -0.046742            -0.052449
# 2    -0.292337  -2.379864            -0.046742            -0.052449
# 3     0.360998   2.174468            -0.243102             0.072704
# 4     1.649503   1.117231             1.152947             1.836146
#
#    generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0            -0.050215            -0.039359            -0.061174
# 1            -0.050215            -0.039359            -0.061174
# 2            -0.050215            -0.039359            -0.061174
# 3             0.083178            -0.185637            -0.184018
# 4             1.842814             1.621580             1.919439

# %% [markdown]
# ## Now checking remove skewness

# %%
Global_ppdp.skew()
# Out:
# capacity_mw            0.022164
# latitude              -0.149698
# longitude              0.002926
# primary_fuel           0.472251
# generation_gwh_2014    0.285906
# generation_gwh_2015    0.222151
# generation_gwh_2016    0.204011
# generation_gwh_2017    0.196816
# generation_gwh_2018    0.193103
# dtype: float64

# %% [markdown]
# # 1) Seprating Target (capacity_mw) and feature variable

# %%
x = Global_ppdp.drop('capacity_mw', axis=1)      #Atttition is target variable
y = Global_ppdp['capacity_mw']

# %%
x
# Out:
#      latitude  longitude  primary_fuel  generation_gwh_2014  \
# 0     28.1839  -0.952545             6            -0.046742
# 1     24.7663  -0.544976             1            -0.046742
# 2     21.9038  -2.379864             7            -0.046742
# 3     23.8712   2.174468             2            -0.243102
# 4     21.9603   1.117231             1             1.152947
# ..        ...        ...           ...                  ...
# 902   16.2949   0.153591             1            -0.046742
# 903   12.8932   0.332870             6            -0.046742
# 904   15.2758  -0.280819             7            -0.046742
# 905   24.3500  -0.796374             1            -0.046742
# 906    9.9344   0.180889             7            -0.046742
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0              -0.052449            -0.050215            -0.039359
# 1              -0.052449            -0.050215            -0.039359
# ...

# %%
#Shape of x

x.shape
# Out:
# (907, 8)

# %%
y
# Out:
# 0     -1.695767
# 1      0.193694
# 2     -0.292337
# 3      0.360998
# 4      1.649503
#          ...
# 902    1.593509
# 903   -1.615576
# 904   -0.522773
# 905    0.086915
# 906   -0.755891
# Name: capacity_mw, Length: 907, dtype: float64

# %%
#Shape of y

y.shape
# Out:
# (907,)

# %% [markdown]
# ## Standard scalling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(x)

# %% [markdown]
# # Creating train_test_split

# %%
#Import train test split from sklearn(Model selection)

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_scale,y, random_state=42, test_size=.33)

print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (607, 8)
# Training target vector size: (607,)
# Test feature matrix size: (300, 8)
# Test target vector size: (300,)

# %% [markdown]
# ## Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(Global_ppdp.values,i) for i in range(Global_ppdp.shape[1])]
vif['Features']= Global_ppdp.columns
vif
# Out:
#          VIF             Features
# 0   1.598783          capacity_mw
# 1   3.310815             latitude
# 2   1.196236            longitude
# 3   3.736305         primary_fuel
# 4   4.045251  generation_gwh_2014
# 5   6.826602  generation_gwh_2015
# 6  11.031541  generation_gwh_2016
# 7   9.922990  generation_gwh_2017
# 8   9.646430  generation_gwh_2018

# %% [markdown]
# ## Machine learning model building

# %%
#Import necessary libraries

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# ## Linear regression

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print("R2_Score:",r2_score(y_test,pred_LR))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:-",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:-",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_Score: 0.25914089877737756
# R2_Score on training Data: 42.261968981121214
# Mean Absolute Error:- 0.659906396490849
# Mean Squared Error:- 0.6452965897915891
# Root Mean Squared Error:- 0.8033035477275008

# %% [markdown]
# ### Cross validation score from linear regression

# %%
from sklearn.model_selection import cross_val_score

# %%
#LINEAR REGRESSION

score = cross_val_score(LR,x,y)
      
print('\033[1m','Cross Validation score of Logistics Regression is :','\033[0m','\n')
print('Score :',score)
print('Mean Score :', score.mean())
print('Standard Deviation :',score.std())
print("Difference between R2 score and cross validation score is - ", (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
#  Cross Validation score of Logistics Regression is :
#
# Score : [0.38180493 0.26170387 0.39165529 0.35457994 0.43856126]
# Mean Score : 0.36566105708791724
# Standard Deviation : 0.05861851548363024
# Difference between R2 score and cross validation score is -  -10.652015831053967

# %% [markdown]
# # Applying other Regression Model, Evaluation & Crossvalidation

# %%
RFR = RandomForestRegressor()
DTC = DecisionTreeRegressor()
ABR = AdaBoostRegressor()
GBR = GradientBoostingRegressor()
RD = Ridge()
LASSO = Lasso()

model = [RFR, DTC, ABR, GBR, RD, LASSO,]


for i in model:
    i.fit(x_train,y_train)
    i.score(x_train,y_train)
    y_pred = i.predict(x_test)
    print('\n')                                        
    print('\033[1m','Error of ', i, ':' ,'\033[0m','\n')
    print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
    print('Mean squared error :', mean_squared_error(y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
    print('\n')

    print('\033[1m',' R2 Score :','\033[0m','\n')
    print(r2_score(y_test,y_pred)) 
    print('===========================================================================')
# Out:
#  Error of  RandomForestRegressor() :
#
# Mean absolute error : 0.29999285021554895
# Mean squared error : 0.15973057569800303
# Root Mean Squared Error: 0.399663077726731
#
#
#   R2 Score :
#
# 0.8166147898168592
# ...
#
#
#  Error of  DecisionTreeRegressor() :
#
# Mean absolute error : 0.3677521034925595
# Mean squared error : 0.2560613417455796
# Root Mean Squared Error: 0.5060250406309748
#
#
#   R2 Score :
#
# 0.7060183200956356
# ...
#
#
#  Error of  AdaBoostRegressor() :
#
# Mean absolute error : 0.3704439841651571
# Mean squared error : 0.22566213838748078
# Root Mean Squared Error: 0.4750390914308851
#
#
#   R2 Score :
#
# 0.740919366891867
# ...
#
#
#  Error of  GradientBoostingRegressor() :
#
# Mean absolute error : 0.3052577970571031
# Mean squared error : 0.16946899669702628
# Root Mean Squared Error: 0.4116661228435324
#
#
#   R2 Score :
#
# 0.8054341979110596
# ...
#
#
#  Error of  Ridge() :
#
# Mean absolute error : 0.6596782116032929
# Mean squared error : 0.6447235849919157
# ...

# %%
#Cross Validation

model = [RFR, DTC, ABR, GBR, RD, LASSO,]

for i in model:
    score = cross_val_score(i, x, y, cv =5)
    print('\n')
    print('\033[1m','Cross Validation Score :',i,":",'\033[0m','\n')
    print("Mean CV Score :",score.mean())
    print('======================================================================')
# Out:
#  Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.8081853978958622
# ...
#
#
#  Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.6645162393208207
# ...
#
#
#  Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.7482796702317465
# ...
#
#
#  Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.8040129051515983
# ...
#
#
#  Cross Validation Score : Ridge() :
#
# Mean CV Score : 0.36592089997947247
# ...
#
#
#  Cross Validation Score : Lasso() :
#
# Mean CV Score : 0.08795063143859985
# ...

# %% [markdown]
# __WE can see here in all models R2 score but Random Forest Regressor gave us maximum R2 score of 0.8166 and minimum Root mean squared error value of 0.3996. So now we will perform Hyper Parameter Tuning on Random Forest Regressor.__

# %% [markdown]
# ## Hyper parameter tuning

# %%
#Import library

from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {'n_estimators':[30,60,80],
              'max_depth': [10,20,40],
              'min_samples_leaf':[5,10],
              'criterion':['mse','mae'],
              'max_features':["auto","sqrt","log2"]}

# %%
randm_src = RandomizedSearchCV(RandomForestRegressor(), param_distributions = parameters,
                               cv = 5, n_iter = 10, n_jobs=-1)

# %%
randm_src.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'criterion': ['mse', 'mae'],
#                                         'max_depth': [10, 20, 40],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [5, 10],
#                                         'n_estimators': [30, 60, 80]})

# %% [markdown]
# ## Final model

# %%
from sklearn.ensemble import RandomForestRegressor
Final_mod =  RandomForestRegressor(n_estimators=60 ,criterion = 'mse', max_depth= 20, max_features = 'auto',
             min_samples_leaf = 5, min_samples_split = 10)
Final_mod.fit(x_train,y_train)
y_pred=Final_mod.predict(x_test)
print('\n')                                        
print('\033[1m',' Error in Final Model :','\033[0m', '\033[0m', '\n')
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('\n')
print('\033[1m',' R2 Score of Final Model :','\033[0m')
print(r2_score(y_test,y_pred)) 
print('\n')
# Out:
#   Error in Final Model :
#
# Mean absolute error : 0.3021202069207204
# Mean squared error : 0.16409555900193662
# Root Mean Squared Error: 0.40508710051288555
#
#
#   R2 Score of Final Model :
# 0.8116033924864496

# %% [markdown]
# ## Saving model

# %%
import joblib
joblib.dump(Final_mod,'Global_ppdp_capacity_mw.pkl')
# Out:
# ['Global_ppdp_capacity_mw.pkl']

# %% [markdown]
# # 2) Seprating Target (Primary Fuel) and feature variable

# %%
x = Global_ppdp.drop('primary_fuel', axis=1)      #Atttition is target variable
y = Global_ppdp['primary_fuel']

# %%
x
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2014  \
# 0      -1.695767   28.1839  -0.952545            -0.046742
# 1       0.193694   24.7663  -0.544976            -0.046742
# 2      -0.292337   21.9038  -2.379864            -0.046742
# 3       0.360998   23.8712   2.174468            -0.243102
# 4       1.649503   21.9603   1.117231             1.152947
# ..           ...       ...        ...                  ...
# 902     1.593509   16.2949   0.153591            -0.046742
# 903    -1.615576   12.8932   0.332870            -0.046742
# 904    -0.522773   15.2758  -0.280819            -0.046742
# 905     0.086915   24.3500  -0.796374            -0.046742
# 906    -0.755891    9.9344   0.180889            -0.046742
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0              -0.052449            -0.050215            -0.039359
# 1              -0.052449            -0.050215            -0.039359
# ...

# %%
#Shape of the dataset

x.shape
# Out:
# (907, 8)

# %%
y
# Out:
# 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 902    1
# 903    6
# 904    7
# 905    1
# 906    7
# Name: primary_fuel, Length: 907, dtype: int32

# %%
#Shape of the dataset

y.shape
# Out:
# (907,)

# %% [markdown]
# ## Creating train_test_split

# %%
#Import train test split from sklearn(Model selection)

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, random_state=42, test_size=.33)

print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (607, 8)
# Training target vector size: (607,)
# Test feature matrix size: (300, 8)
# Test target vector size: (300,)

# %%
from sklearn.preprocessing import StandardScaler
Scaler_X = StandardScaler()
x_train = Scaler_X.fit_transform(x_train)
x_test = Scaler_X.transform(x_test)

# %% [markdown]
# # Linear Regression

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print("R2_Score:",r2_score(y_test,pred_LR))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:-",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:-",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_Score: 0.31239622084581753
# R2_Score on training Data: 35.396446595537725
# Mean Absolute Error:- 1.47186317731118
# Mean Squared Error:- 3.3342365653705746
# Root Mean Squared Error:- 1.825989201876773

# %% [markdown]
# ### Cross validation score from linear regression

# %%
#LINEAR REGRESSION

score = cross_val_score(LR,x,y)
      
print('\033[1m','Cross Validation score of Logistics Regression is :','\033[0m','\n')
print('Score :',score)
print('Mean Score :', score.mean())
print('Standard Deviation :',score.std())
print("Difference between R2 score and cross validation score is - ", (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
#  Cross Validation score of Logistics Regression is :
#
# Score : [0.32810751 0.28682767 0.37563492 0.28616449 0.33239429]
# Mean Score : 0.321825775313813
# Standard Deviation : 0.03329616237004305
# Difference between R2 score and cross validation score is -  -0.9429554467995482

# %% [markdown]
# # Applying other Regression Model, Evaluation & Crossvalidation

# %%
RFR = RandomForestRegressor()
DTC = DecisionTreeRegressor()
ABR = AdaBoostRegressor()
GBR = GradientBoostingRegressor()
RD = Ridge()
LASSO = Lasso()

model = [RFR, DTC, ABR, GBR, RD, LASSO,]


for i in model:
    i.fit(x_train,y_train)
    i.score(x_train,y_train)
    y_pred = i.predict(x_test)
    print('\n')                                        
    print('\033[1m','Error of ', i, ':' ,'\033[0m','\n')
    print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
    print('Mean squared error :', mean_squared_error(y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
    print('\n')

    print('\033[1m',' R2 Score :','\033[0m','\n')
    print(r2_score(y_test,y_pred)) 
    print('===========================================================================')
# Out:
#  Error of  RandomForestRegressor() :
#
# Mean absolute error : 0.9912307936507936
# Mean squared error : 2.256276393922903
# Root Mean Squared Error: 1.5020906743345765
#
#
#   R2 Score :
#
# 0.534698829893814
# ...
#
#
#  Error of  DecisionTreeRegressor() :
#
# Mean absolute error : 1.0266666666666666
# Mean squared error : 3.8666666666666667
# Root Mean Squared Error: 1.96638416050035
#
#
#   R2 Score :
#
# 0.20259568851737797
# ...
#
#
#  Error of  AdaBoostRegressor() :
#
# Mean absolute error : 1.2690582297379698
# Mean squared error : 2.9557579558774996
# Root Mean Squared Error: 1.7192317923646885
#
#
#   R2 Score :
#
# 0.3904480678321258
# ...
#
#
#  Error of  GradientBoostingRegressor() :
#
# Mean absolute error : 1.1543213235063665
# Mean squared error : 2.522139418971248
# Root Mean Squared Error: 1.5881244973147566
#
#
#   R2 Score :
#
# 0.4798711602979444
# ...
#
#
#  Error of  Ridge() :
#
# Mean absolute error : 1.4719848168054532
# Mean squared error : 3.3340740029089595
# ...

# %%
#Cross Validation

model = [RFR, DTC, ABR, GBR, RD, LASSO,]

for i in model:
    score = cross_val_score(i, x, y, cv =5)
    print('\n')
    print('\033[1m','Cross Validation Score :',i,":",'\033[0m','\n')
    print("Mean CV Score :",score.mean())
    print('======================================================================')
# Out:
#  Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.592800384957149
# ...
#
#
#  Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.2086148635186605
# ...
#
#
#  Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.3933725293999316
# ...
#
#
#  Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.502789896785038
# ...
#
#
#  Cross Validation Score : Ridge() :
#
# Mean CV Score : 0.3218618086712126
# ...
#
#
#  Cross Validation Score : Lasso() :
#
# Mean CV Score : 0.07910241286452627
# ...

# %% [markdown]
# __WE can see here in all models R2 score but Random Forest Regressor gave us maximum R2 score of 0.5346 and minimum Root mean squared error value of 1.5020. So now we will perform Hyper Parameter Tuning on Random Forest Regressor.__

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {'n_estimators':[30,60,80],
              'max_depth': [10,20,40],
              'min_samples_leaf':[5,10],
              'criterion':['mse','mae'],
              'max_features':["auto","sqrt","log2"]}

# %%
randm_src = RandomizedSearchCV(RandomForestRegressor(), param_distributions = parameters,
                               cv = 5, n_iter = 10, n_jobs=-1)

# %%
randm_src.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'criterion': ['mse', 'mae'],
#                                         'max_depth': [10, 20, 40],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [5, 10],
#                                         'n_estimators': [30, 60, 80]})

# %% [markdown]
# ## Final model

# %%
from sklearn.ensemble import RandomForestRegressor
Final_mod =  RandomForestRegressor(n_estimators=30 ,criterion = 'mse', max_depth= 20, max_features = 'auto',
             min_samples_leaf = 5, min_samples_split = 10)
Final_mod.fit(x_train,y_train)
y_pred=Final_mod.predict(x_test)
print('\n')                                        
print('\033[1m',' Error in Final Model :','\033[0m', '\033[0m', '\n')
print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
print('Mean squared error :', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('\n')
print('\033[1m',' R2 Score of Final Model :','\033[0m')
print(r2_score(y_test,y_pred)) 
print('\n')
# Out:
#   Error in Final Model :
#
# Mean absolute error : 1.0979643224208806
# Mean squared error : 2.4536283624952206
# Root Mean Squared Error: 1.5664061933276505
#
#
#   R2 Score of Final Model :
# 0.4939998702509306

# %% [markdown]
# ## Saving model

# %%
import joblib
joblib.dump(Final_mod,'Global_ppdp_primary_fuel.pkl')
# Out:
# ['Global_ppdp_primary_fuel.pkl']
