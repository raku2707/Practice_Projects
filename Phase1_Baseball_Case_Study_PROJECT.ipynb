# %%
#Import some necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#Create dataframe and read csv data from github

Baseball_cs = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
Baseball_cs
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
#Shape of the dataset

Baseball_cs.shape
# Out:
# (30, 17)

# %%
#Information of the dataset

Baseball_cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# ###### > We can see this datset has only numeric data and no column has categorical data.

# %%
#Cheking cloumns names

Baseball_cs.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
#     This column names present in our data.
#     Total 17 columns in dataset.
#     r, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, and E columns are input features variable and W ('Wins') is target variable.

# %% [markdown]
# ## Information of the dataset
#
# ##### Input features variable-
#
#     ● R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#     ● AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#     ● H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#     ● 2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#     ● 3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#     ● HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#     ● BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#     ● SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#     ● SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#     ● RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#     ● ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#     ● ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#     ● CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#     ● SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#     ● SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#     ● E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# ##### Target variable-
#     ● W - Number of predicted wins (W)

# %% [markdown]
# ## Now rename columns name in dataset

# %%
Baseball_cs.rename(columns={'W' : 'Number of predicted wins', 'R' : 'Runs Scored', 'AB' : 'At Bat or Time at bat',
                            'H' : 'Hits or Base hit', '2B' : 'Two-bagger" or Two-base hit', '3B' : 'Three-bagger" or Three-base hit',
                            'HR' : 'Home Runs', 'BB' : 'Base on Balls or Walk', 'SO' : 'Strike Outs', 'SB' : 'Stolen Base',
                            'RA' : 'Runs Average', 'ER' : 'Earned Runs', 'ERA' : 'Earned Run Average', 'CG' : 'Complete Game',
                            'SHO' : 'Shut Outs', 'SV' : 'Saves', 'E' : 'Errors'}, inplace=True)

Baseball_cs.head()
# Out:
#    Number of predicted wins  Runs Scored  At Bat or Time at bat  \
# 0                        95          724                   5575
# 1                        83          696                   5467
# 2                        81          669                   5439
# 3                        76          622                   5533
# 4                        74          689                   5605
#
#    Hits or Base hit  Two-bagger" or Two-base hit  \
# 0              1497                          300
# 1              1349                          277
# 2              1395                          303
# 3              1381                          260
# 4              1515                          289
#
#    Three-bagger" or Three-base hit  Home Runs  Base on Balls or Walk  \
# 0                               42        139                    383
# 1                               44        156                    439
# 2                               29        141                    533
# 3                               27        136                    404
# 4                               49        151                    455
#
#    Strike Outs  Stolen Base  Runs Average  Earned Runs  Earned Run Average  \
# 0          973          104           641          601                3.73
# 1         1264           70           700          653                4.07
# 2         1157           86           640          584                3.67
# 3         1231           68           701          643                3.98
# 4         1259           83           803          746                4.64
#
#    Complete Game  Shut Outs  Saves  Errors
# 0              2          8     56      88
# 1              2         12     45      86
# 2             11         10     38      79
# 3              7          9     37     101
# 4              7         12     35      86

# %%
#Statistical summary of the dataset

Baseball_cs.describe()
# Out:
#        Number of predicted wins  Runs Scored  At Bat or Time at bat  \
# count                 30.000000    30.000000              30.000000
# mean                  80.966667   688.233333            5516.266667
# std                   10.453455    58.761754              70.467372
# min                   63.000000   573.000000            5385.000000
# 25%                   74.000000   651.250000            5464.000000
# 50%                   81.000000   689.000000            5510.000000
# 75%                   87.750000   718.250000            5570.000000
# max                  100.000000   891.000000            5649.000000
#
#        Hits or Base hit  Two-bagger" or Two-base hit  \
# count         30.000000                    30.000000
# mean        1403.533333                   274.733333
# std           57.140923                    18.095405
# min         1324.000000                   236.000000
# 25%         1363.000000                   262.250000
# 50%         1382.500000                   275.500000
# 75%         1451.500000                   288.750000
# max         1515.000000                   308.000000
#
#        Three-bagger" or Three-base hit   Home Runs  Base on Balls or Walk  \
# count                        30.000000   30.000000              30.000000
# mean                         31.300000  163.633333             469.100000
# std                          10.452355   31.823309              57.053725
# min                          13.000000  100.000000             375.000000
# 25%                          23.000000  140.250000             428.250000
# 50%                          31.000000  158.500000             473.000000
# 75%                          39.000000  177.000000             501.250000
# max                          49.000000  232.000000             570.000000
#
#        Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# count     30.00000    30.000000     30.000000    30.000000
# mean    1248.20000    83.500000    688.233333   635.833333
# std      103.75947    22.815225     72.108005    70.140786
# min      973.00000    44.000000    525.000000   478.000000
# 25%     1157.50000    69.000000    636.250000   587.250000
# 50%     1261.50000    83.500000    695.500000   644.500000
# 75%     1311.50000    96.500000    732.500000   679.250000
# max     1518.00000   134.000000    844.000000   799.000000
#
#        Earned Run Average  Complete Game  Shut Outs      Saves      Errors
# count           30.000000      30.000000  30.000000  30.000000   30.000000
# mean             3.956333       3.466667  11.300000  43.066667   94.333333
# std              0.454089       2.763473   4.120177   7.869335   13.958889
# min              2.940000       0.000000   4.000000  28.000000   75.000000
# 25%              3.682500       1.000000   9.000000  37.250000   86.000000
# 50%              4.025000       3.000000  12.000000  42.000000   91.000000
# 75%              4.220000       5.750000  13.000000  46.750000   96.750000
# max              5.040000      11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# ## Checking missing values using heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(Baseball_cs.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no any missing values (null values) present in dataset.

# %% [markdown]
# ## Checking correlation between all columns

# %%
Baseball_cs.corr()
# Out:
#                                  Number of predicted wins  Runs Scored  \
# Number of predicted wins                         1.000000     0.430751
# Runs Scored                                      0.430751     1.000000
# At Bat or Time at bat                           -0.087947     0.319464
# Hits or Base hit                                 0.037612     0.482856
# Two-bagger" or Two-base hit                      0.427797     0.560084
# Three-bagger" or Three-base hit                 -0.251118    -0.070072
# Home Runs                                        0.307407     0.671283
# Base on Balls or Walk                            0.484342     0.402452
# Strike Outs                                      0.111850    -0.054726
# Stolen Base                                     -0.157234     0.081367
# Runs Average                                    -0.812952    -0.041623
# Earned Runs                                     -0.809435    -0.041245
# Earned Run Average                              -0.819600    -0.049281
# Complete Game                                    0.080533     0.232042
# Shut Outs                                        0.471805    -0.103274
# Saves                                            0.666530    -0.096380
# Errors                                          -0.089485    -0.023262
#
#                                  At Bat or Time at bat  Hits or Base hit  \
# Number of predicted wins                     -0.087947          0.037612
# Runs Scored                                   0.319464          0.482856
# At Bat or Time at bat                         1.000000          0.739122
# Hits or Base hit                              0.739122          1.000000
# Two-bagger" or Two-base hit                   0.453370          0.566847
# Three-bagger" or Three-base hit               0.435422          0.478694
# Home Runs                                    -0.066983         -0.090855
# Base on Balls or Walk                        -0.136414         -0.118281
# Strike Outs                                  -0.106022         -0.398830
# Stolen Base                                   0.372618          0.413444
# Runs Average                                  0.316010          0.224324
# Earned Runs                                   0.309686          0.252489
# Earned Run Average                            0.255551          0.231172
# Complete Game                                -0.080876          0.147955
# Shut Outs                                    -0.197321         -0.145559
# Saves                                        -0.106367         -0.130371
# Errors                                        0.316743         -0.033173
#
#                                  Two-bagger" or Two-base hit  \
# Number of predicted wins                            0.427797
# Runs Scored                                         0.560084
# At Bat or Time at bat                               0.453370
# Hits or Base hit                                    0.566847
# Two-bagger" or Two-base hit                         1.000000
# Three-bagger" or Three-base hit                     0.220490
# Home Runs                                           0.056292
# Base on Balls or Walk                               0.302700
# Strike Outs                                        -0.150752
# Stolen Base                                         0.195027
# Runs Average                                       -0.218160
# Earned Runs                                        -0.235531
# Earned Run Average                                 -0.254854
# Complete Game                                       0.306675
# Shut Outs                                           0.057998
# Saves                                               0.171576
# Errors                                              0.105754
#
#                                  Three-bagger" or Three-base hit  Home Runs  \
# Number of predicted wins                               -0.251118   0.307407
# Runs Scored                                            -0.070072   0.671283
# At Bat or Time at bat                                   0.435422  -0.066983
# Hits or Base hit                                        0.478694  -0.090855
# Two-bagger" or Two-base hit                             0.220490   0.056292
# Three-bagger" or Three-base hit                         1.000000  -0.430915
# Home Runs                                              -0.430915   1.000000
# Base on Balls or Walk                                  -0.454949   0.425691
# Strike Outs                                            -0.141196   0.359923
# Stolen Base                                             0.457437  -0.136567
# Runs Average                                            0.314125  -0.103903
# Earned Runs                                             0.340225  -0.085922
# Earned Run Average                                      0.330951  -0.090917
# Complete Game                                          -0.065898   0.156502
# Shut Outs                                              -0.041396  -0.019119
# Saves                                                  -0.142370  -0.028540
# Errors                                                  0.126678  -0.207597
#
#                                  Base on Balls or Walk  Strike Outs  \
# Number of predicted wins                      0.484342     0.111850
# Runs Scored                                   0.402452    -0.054726
# At Bat or Time at bat                        -0.136414    -0.106022
# Hits or Base hit                             -0.118281    -0.398830
# Two-bagger" or Two-base hit                   0.302700    -0.150752
# Three-bagger" or Three-base hit              -0.454949    -0.141196
# Home Runs                                     0.425691     0.359923
# Base on Balls or Walk                         1.000000     0.233652
# Strike Outs                                   0.233652     1.000000
# Stolen Base                                  -0.098347     0.030968
# Runs Average                                 -0.416445    -0.129745
# Earned Runs                                  -0.452663    -0.161612
# Earned Run Average                           -0.459832    -0.180368
# Complete Game                                 0.462478    -0.093418
# Shut Outs                                     0.426004     0.237721
# Saves                                         0.099445     0.126297
# Errors                                       -0.075685     0.155133
#
#                                  Stolen Base  Runs Average  Earned Runs  \
# Number of predicted wins           -0.157234     -0.812952    -0.809435
# Runs Scored                         0.081367     -0.041623    -0.041245
# At Bat or Time at bat               0.372618      0.316010     0.309686
# Hits or Base hit                    0.413444      0.224324     0.252489
# Two-bagger" or Two-base hit         0.195027     -0.218160    -0.235531
# Three-bagger" or Three-base hit     0.457437      0.314125     0.340225
# Home Runs                          -0.136567     -0.103903    -0.085922
# Base on Balls or Walk              -0.098347     -0.416445    -0.452663
# Strike Outs                         0.030968     -0.129745    -0.161612
# Stolen Base                         1.000000      0.132290     0.143068
# Runs Average                        0.132290      1.000000     0.991018
# Earned Runs                         0.143068      0.991018     1.000000
# Earned Run Average                  0.126063      0.986674     0.997248
# Complete Game                      -0.020783     -0.016659    -0.020221
# Shut Outs                          -0.106563     -0.636862    -0.630192
# Saves                              -0.183418     -0.616224    -0.589663
# Errors                              0.079149      0.198996     0.136921
#
#                                  Earned Run Average  Complete Game  Shut Outs  \
# Number of predicted wins                  -0.819600       0.080533   0.471805
# Runs Scored                               -0.049281       0.232042  -0.103274
# At Bat or Time at bat                      0.255551      -0.080876  -0.197321
# Hits or Base hit                           0.231172       0.147955  -0.145559
# Two-bagger" or Two-base hit               -0.254854       0.306675   0.057998
# Three-bagger" or Three-base hit            0.330951      -0.065898  -0.041396
# Home Runs                                 -0.090917       0.156502  -0.019119
# Base on Balls or Walk                     -0.459832       0.462478   0.426004
# Strike Outs                               -0.180368      -0.093418   0.237721
# Stolen Base                                0.126063      -0.020783  -0.106563
# Runs Average                               0.986674      -0.016659  -0.636862
# Earned Runs                                0.997248      -0.020221  -0.630192
# Earned Run Average                         1.000000      -0.009856  -0.630833
# Complete Game                             -0.009856       1.000000   0.241676
# Shut Outs                                 -0.630833       0.241676   1.000000
# Saves                                     -0.607005      -0.367766   0.221639
# Errors                                     0.113137      -0.140047  -0.115716
#
#                                     Saves    Errors
# Number of predicted wins         0.666530 -0.089485
# Runs Scored                     -0.096380 -0.023262
# At Bat or Time at bat           -0.106367  0.316743
# Hits or Base hit                -0.130371 -0.033173
# Two-bagger" or Two-base hit      0.171576  0.105754
# Three-bagger" or Three-base hit -0.142370  0.126678
# Home Runs                       -0.028540 -0.207597
# Base on Balls or Walk            0.099445 -0.075685
# Strike Outs                      0.126297  0.155133
# Stolen Base                     -0.183418  0.079149
# Runs Average                    -0.616224  0.198996
# Earned Runs                     -0.589663  0.136921
# Earned Run Average              -0.607005  0.113137
# Complete Game                   -0.367766 -0.140047
# Shut Outs                        0.221639 -0.115716
# Saves                            1.000000 -0.025636
# Errors                          -0.025636  1.000000

# %%
#Visualize correlation by plotting heatmap

plt.figure(figsize=(20,10))
sns.heatmap(Baseball_cs.corr(), annot = True, linewidth= 0.2, linecolor = 'black', cmap = 'coolwarm')
plt.show()

# %% [markdown]
# ## Checking outliers from each column

# %%
#Let's check the outliers by plotting boxplot.

plt.figure(figsize=(20,20))
plotnumber=1

for i in Baseball_cs:
    if plotnumber <=20:
        plt.subplot(5,4,plotnumber)        #in subplot method we are taking basically 3 argumrnts ( 5 is represent of number of rows, 4 is represent of number of columns and plotnumber is represent of indes of the plot
        sns.boxplot(Baseball_cs[i], palette='Set2_r')
        plt.xlabel(i, fontsize = 15)
    plotnumber+=1
    
plt.show()

# %% [markdown]
# Clearly we can see Run scored, Earned run average, Shut outs and saves has only one outiler and errors column has 4+ outliers and other columns has no outliers.

# %% [markdown]
# ## Checking the data distributed in each column

# %%
plt.figure(figsize=(20,25), facecolor='White')
plotnumber =1

for column in Baseball_cs:
    if plotnumber <=20:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(Baseball_cs[column], color='g')
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# Clearly we can see some of feature are either left or right skewed.

# %% [markdown]
# # Visualize barplot
#
# ## Now checking Number of wins with each variable.

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="Number of predicted wins", y="Runs Scored", data=Baseball_cs)

plt.figure(figsize=(15,6))
sns.barplot(x="Number of predicted wins", y="Base on Balls or Walk", data=Baseball_cs)

plt.figure(figsize=(15,6))
sns.barplot(x="Number of predicted wins", y="Runs Average", data=Baseball_cs)

plt.figure(figsize=(15,6))
sns.barplot(x="Number of predicted wins", y="Earned Runs", data=Baseball_cs)

plt.show()

# %% [markdown]
#     RUN SCORED = We can see that many time run scored above 600 for winning team.
#     BASE ON BALLS OR WALK = We can see that base on ball above 400 really contribute in Wins in team
#     RUNS AVERAGE = More Run Average gives advantage to hitter and here as wins are high even at low run this clearly means that perforamance of pitcher is better than hitter.
#     EARNED RUNS = Earned runs is low for maximum wins.

# %% [markdown]
# ### Now comparision between Run average and Earned runs average

# %%
# Checking the relation between two variables

sns.set_palette('Set1')

plt.figure(figsize=[16,8])
plt.title('Comparison between Run Average and Earned Run Average', fontsize =20)
sns.stripplot(Baseball_cs['Runs Average'],Baseball_cs['Earned Run Average'],hue=Baseball_cs['Number of predicted wins'])
plt.xlabel('Runs Average',fontsize =16)
plt.ylabel("Earned Average",fontsize =16)
# Out:
# Text(0, 0.5, 'Earned Average')

# %% [markdown]
# ## Checking skewness from dataset

# %%
Baseball_cs.skew()
# Out:
# Number of predicted wins           0.047089
# Runs Scored                        1.200786
# At Bat or Time at bat              0.183437
# Hits or Base hit                   0.670254
# Two-bagger" or Two-base hit       -0.230650
# Three-bagger" or Three-base hit    0.129502
# Home Runs                          0.516441
# Base on Balls or Walk              0.158498
# Strike Outs                       -0.156065
# Stolen Base                        0.479893
# Runs Average                       0.045734
# Earned Runs                        0.058710
# Earned Run Average                 0.053331
# Complete Game                      0.736845
# Shut Outs                          0.565790
# Saves                              0.657524
# Errors                             0.890132
# dtype: float64

# %% [markdown]
# ## Visualize distplot from dataset

# %%
#Let's visualize distplot from columns

plt.figure(figsize=(20,25), facecolor='Red')
plotnumber =1

for column in Baseball_cs:
    if plotnumber <=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(Baseball_cs[column], color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
    
plt.show()

# %% [markdown]
# # Seprating independent and dependent variable

# %%
x=Baseball_cs.drop(['Number of predicted wins'],axis=1) #contain all  independent variable
y=Baseball_cs['Number of predicted wins']

# %%
x
# Out:
#     Runs Scored  At Bat or Time at bat  Hits or Base hit  \
# 0           724                   5575              1497
# 1           696                   5467              1349
# 2           669                   5439              1395
# 3           622                   5533              1381
# 4           689                   5605              1515
# 5           891                   5509              1480
# 6           764                   5567              1397
# 7           713                   5485              1370
# 8           644                   5485              1383
# 9           748                   5640              1495
# 10          751                   5511              1419
# 11          729                   5459              1363
# 12          661                   5417              1331
# 13          656                   5544              1379
# 14          694                   5600              1405
# 15          647                   5484              1386
# 16          697                   5631              1462
# 17          689                   5491              1341
# 18          655                   5480              1378
# 19          640                   5571              1382
# 20          683                   5527              1351
# 21          703                   5428              1363
# 22          613                   5463              1420
# 23          573                   5420              1361
# 24          626                   5529              1374
# 25          667                   5385              1346
# 26          696                   5565              1486
# 27          720                   5649              1494
# 28          650                   5457              1324
# 29          737                   5572              1479
#
#     Two-bagger" or Two-base hit  Three-bagger" or Three-base hit  Home Runs  \
# 0                           300                               42        139
# 1                           277                               44        156
# 2                           303                               29        141
# 3                           260                               27        136
# 4                           289                               49        151
# 5                           308                               17        232
# 6                           272                               19        212
# 7                           246                               20        217
# 8                           278                               32        167
# 9                           294                               33        161
# 10                          279                               32        172
# 11                          278                               26        230
# 12                          243                               21        176
# 13                          262                               22        198
# 14                          277                               46        146
# 15                          288                               39        137
# 16                          292                               27        140
# 17                          272                               30        171
# 18                          274                               34        145
# 19                          257                               27        167
# 20                          295                               17        177
# 21                          265                               13        177
# 22                          236                               40        120
# 23                          251                               18        100
# 24                          272                               37        130
# 25                          263                               26        187
# 26                          288                               39        136
# 27                          289                               48        154
# 28                          260                               36        148
# 29                          274                               49        186
#
#     Base on Balls or Walk  Strike Outs  Stolen Base  Runs Average  \
# 0                     383          973          104           641
# 1                     439         1264           70           700
# 2                     533         1157           86           640
# 3                     404         1231           68           701
# 4                     455         1259           83           803
# 5                     570         1151           88           670
# 6                     554         1227           63           698
# 7                     418         1331           44           693
# 8                     436         1310           87           642
# 9                     478         1148           71           753
# 10                    503         1233          101           733
# 11                    486         1392          121           618
# 12                    435         1150           52           675
# 13                    478         1336           69           726
# 14                    475         1119           78           729
# 15                    506         1267           69           525
# 16                    461         1322           98           596
# 17                    567         1518           95           608
# 18                    412         1299           84           737
# 19                    496         1255          134           754
# 20                    488         1290           51           613
# 21                    539         1344           57           635
# 22                    375         1150          112           678
# 23                    471         1107           69           760
# 24                    387         1274           88           809
# 25                    563         1258           59           595
# 26                    457         1159           93           627
# 27                    490         1312          132           713
# 28                    426         1327           82           731
# 29                    388         1283           97           844
#
#     Earned Runs  Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 0           601                3.73              2          8     56      88
# 1           653                4.07              2         12     45      86
# 2           584                3.67             11         10     38      79
# 3           643                3.98              7          9     37     101
# 4           746                4.64              7         12     35      86
# 5           609                3.80              7         10     34      88
# 6           652                4.03              3          4     48      93
# 7           646                4.05              0         10     43      77
# 8           604                3.74              1         12     60      95
# 9           694                4.31              3         10     40      97
# 10          680                4.24              5          9     45     119
# 11          572                3.57              5         13     39      85
# 12          630                3.94              2         12     46      93
# 13          677                4.16              6         12     45      94
# 14          664                4.14              5         15     28     126
# 15          478                2.94              1         15     62      96
# 16          532                3.21              0         13     54     122
# 17          546                3.36              6         21     48     111
# 18          682                4.28              1          7     40     116
# 19          700                4.33              2          8     35      90
# 20          557                3.43              1         14     50      88
# 21          577                3.62              4         13     41      90
# 22          638                4.02              0         12     35      77
# 23          698                4.41              3         10     44      90
# 24          749                4.69              1          7     35     117
# 25          553                3.44              6         21     47      75
# 26          597                3.72              7         18     41      78
# 27          659                4.04              1         12     44      86
# 28          655                4.09              1          6     41      92
# 29          799                5.04              4          4     36      95

# %%
x.shape
# Out:
# (30, 16)

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Number of predicted wins, dtype: int64

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # Machine learning model building

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (20, 16)
# Training target vector size: (20,)
# Test feature matrix size: (10, 16)
# Test target vector size: (10,)

# %%
#Import necessary libraries

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# ## Linear Regression

# %%
LR = LinearRegression()
LR.fit(X_train,Y_train)
pred_LR=LR.predict(X_test)
pred_train=LR.predict(X_train)

print("R2_Score:",r2_score(Y_test,pred_LR))
print("R2_Score on training Data:",r2_score(Y_train,pred_train)*100)
print("Mean Absolute Error:-",mean_absolute_error(Y_test,pred_LR))
print("Mean Squared Error:-",mean_squared_error(Y_test,pred_LR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(Y_test,pred_LR)))
# Out:
# R2_Score: 0.6741942317769304
# R2_Score on training Data: 98.52165036614605
# Mean Absolute Error:- 5.740092406895946
# Mean Squared Error:- 45.79525878143467
# Root Mean Squared Error:- 6.76721942761092

# %% [markdown]
# ## Cross validation score from Linear Regression

# %%
from sklearn.model_selection import cross_val_score

#LINEAR REGRESSION

score = cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ", (r2_score(Y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.71136471 -2.21099237  0.38808753  0.73556937  0.5797478 ]
# 0.04075540667465847
# Difference between R2 score and cross validation score is -  63.34388251022719

# %% [markdown]
# ## Applying other Regression Model, Evaluation & Crossvalidation

# %%
RFR = RandomForestRegressor()
DTC = DecisionTreeRegressor()
ABR = AdaBoostRegressor()
GBR = GradientBoostingRegressor()
RD = Ridge()
LASSO = Lasso()

model = [RFR, DTC, ABR, GBR, RD, LASSO,]


for i in model:
    i.fit(X_train,Y_train)
    i.score(X_train,Y_train)
    y_pred = i.predict(X_test)
    print('\n')                                        
    print('Error of ', i, ':' ,'\n')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print(' R2 Score :',r2_score(Y_test,y_pred))
    print('===========================================================================')
# Out:
# Error of  RandomForestRegressor() :
#
# Mean absolute error : 5.327
# Mean squared error : 47.50067000000001
# Root Mean Squared Error: 6.892072982782467
#
#
#  R2 Score : 0.6620612549800796
# ===========================================================================
#
#
# Error of  DecisionTreeRegressor() :
#
# Mean absolute error : 8.3
# Mean squared error : 86.9
# Root Mean Squared Error: 9.322016949137135
#
#
#  R2 Score : 0.38175867956744447
# ===========================================================================
#
#
# Error of  AdaBoostRegressor() :
#
# Mean absolute error : 5.745
# Mean squared error : 44.49275
# Root Mean Squared Error: 6.67028859945355
#
#
#  R2 Score : 0.6834607996585088
# ===========================================================================
#
#
# Error of  GradientBoostingRegressor() :
#
# Mean absolute error : 5.520031501220018
# Mean squared error : 38.00307199281464
# Root Mean Squared Error: 6.164663169453352
#
#
#  R2 Score : 0.729630961917938
# ===========================================================================
#
#
# Error of  Ridge() :
#
# Mean absolute error : 5.7141025825368805
# Mean squared error : 45.10544986654441
# Root Mean Squared Error: 6.716059102371301
#
#
#  R2 Score : 0.6791018080069406
# ===========================================================================
#
#
# Error of  Lasso() :
#
# Mean absolute error : 4.272538047738076
# Mean squared error : 28.47046785947246
# Root Mean Squared Error: 5.335772470736778
#
#
#  R2 Score : 0.7974497164237873
# ===========================================================================

# %%
#Cross Validation

model = [RFR, DTC, ABR, GBR, RD, LASSO,]

for i in model:
    score = cross_val_score(i, x, y, cv =5)
    print('\n')
    print('Cross Validation Score :',i,":",'\n')
    print("Mean CV Score :",score.mean())
    print('======================================================================')
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : -0.6774604763174993
# ======================================================================
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -1.8540575933288062
# ======================================================================
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : -1.151638415313297
# ======================================================================
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : -1.0917667294202977
# ======================================================================
#
#
# Cross Validation Score : Ridge() :
#
# Mean CV Score : -0.02152912211961755
# ======================================================================
#
#
# Cross Validation Score : Lasso() :
#
# Mean CV Score : 0.32380268561253256
# ======================================================================

# %% [markdown]
# WE can see here in all models R2 score but LASSO gave us maximum R2 score of 0.7974 and minimum Root mean squared error value of 5.3357.  So now we will perform Hyper Parameter Tuning on Random Forest Regressor.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_distributions = {'alpha': [0.01, 0.1, 1]}

# %%
rs = RandomizedSearchCV(Lasso(),param_distributions=param_distributions,
                        cv=2,n_iter=3,random_state=42)

# %%
rs.fit(X_train, Y_train)
# Out:
# RandomizedSearchCV(cv=2, estimator=Lasso(), n_iter=3,
#                    param_distributions={'alpha': [0.01, 0.1, 1]},
#                    random_state=42)

# %%
rs.best_params_
# Out:
# {'alpha': 0.01}

# %% [markdown]
# # Final Model

# %%
from sklearn.ensemble import RandomForestRegressor
Final_mod =  Lasso(alpha = 0.5, fit_intercept= True, normalize = False, max_iter = 250, random_state = 32,selection ='random')

Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print(' Error in Final Model :' +'\n')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
#
# Mean absolute error : 4.376846495435087
# Mean squared error : 29.450344852474434
# Root Mean Squared Error: 5.426817193574373
#
#
#  R2 Score of Final Model :
# 0.7904784799909331

# %%
plt.figure(figsize=(12,7))
y_pred=Final_mod.predict(X_test)
sns.scatterplot(Y_test.round(2), y_pred)
print(' True Values Vs Predicted Value plot :')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.show()
# Out:
#  True Values Vs Predicted Value plot :

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'Baseball_cs.pkl')
# Out:
# ['Baseball_cs.pkl']
